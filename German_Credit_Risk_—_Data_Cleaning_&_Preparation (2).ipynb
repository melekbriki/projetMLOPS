# %% [markdown]
# 📊 German Credit Risk — Data Cleaning &
#
# Preparation

# %% [markdown]
# MLOps Project — Phase 1

# %% [markdown]
# 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

import warnings
warnings.filterwarnings('ignore')

print('✅ Libraries imported successfully')
# Out:
# ✅ Libraries imported successfully

# %% [markdown]
# 2. Load the Dataset

# %%
columns = [
    'Status', 'Duration', 'CreditHistory', 'Purpose', 'CreditAmount',
    'Savings', 'EmploymentDuration', 'InstallmentRate', 'PersonalStatusSex',
    'OtherDebtors', 'ResidenceDuration', 'Property', 'Age',
    'OtherInstallmentPlans', 'Housing', 'ExistingCredits',
    'Job', 'PeopleLiable', 'Telephone', 'ForeignWorker', 'Target'
]

df = pd.read_csv('german.data', sep=' ', header=None, names=columns)
print(f'Dataset shape: {df.shape}')
df.head()
# Out:
# Dataset shape: (1000, 21)
#   Status  Duration CreditHistory Purpose  CreditAmount Savings  \
# 0    A11         6           A34     A43          1169     A65
# 1    A12        48           A32     A43          5951     A61
# 2    A14        12           A34     A46          2096     A61
# 3    A11        42           A32     A42          7882     A61
# 4    A11        24           A33     A40          4870     A61
#
#   EmploymentDuration  InstallmentRate PersonalStatusSex OtherDebtors  ...  \
# 0                A75                4               A93         A101  ...
# 1                A73                2               A92         A101  ...
# 2                A74                2               A93         A101  ...
# 3                A74                2               A93         A103  ...
# 4                A73                3               A93         A101  ...
#
#    Property Age  OtherInstallmentPlans Housing ExistingCredits   Job  \
# 0      A121  67                   A143    A152               2  A173
# 1      A121  22                   A143    A152               1  A173
# 2      A121  49                   A143    A152               1  A172
# 3      A122  45                   A143    A153               1  A173
# 4      A124  53                   A143    A153               2  A173
#
#   PeopleLiable  Telephone ForeignWorker Target
# 0            1       A192          A201      1
# 1            1       A191          A201      2
# 2            2       A191          A201      1
# 3            2       A191          A201      1
# 4            2       A191          A201      2
#
# [5 rows x 21 columns]

# %% [markdown]
# 3. Initial Inspection

# %%
print('=== Column Info ===')
df.info()

print('\n=== Statistical Summary ===')
df.describe()

print('\n=== Unique Values ===')
for col in df.columns:
    print(f'{col}: {df[col].nunique()} unique values')
# Out:
# === Column Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Status                 1000 non-null   object
#  1   Duration               1000 non-null   int64
#  2   CreditHistory          1000 non-null   object
#  3   Purpose                1000 non-null   object
#  4   CreditAmount           1000 non-null   int64
#  5   Savings                1000 non-null   object
#  6   EmploymentDuration     1000 non-null   object
#  7   InstallmentRate        1000 non-null   int64
#  8   PersonalStatusSex      1000 non-null   object
#  9   OtherDebtors           1000 non-null   object
#  10  ResidenceDuration      1000 non-null   int64
#  11  Property               1000 non-null   object
#  12  Age                    1000 non-null   int64
#  13  OtherInstallmentPlans  1000 non-null   object
#  14  Housing                1000 non-null   object
#  15  ExistingCredits        1000 non-null   int64
#  16  Job                    1000 non-null   object
#  17  PeopleLiable           1000 non-null   int64
#  18  Telephone              1000 non-null   object
#  19  ForeignWorker          1000 non-null   object
#  20  Target                 1000 non-null   int64
# dtypes: int64(8), object(13)
# memory usage: 164.2+ KB
#
# === Statistical Summary ===
#
# === Unique Values ===
# Status: 4 unique values
# Duration: 33 unique values
# CreditHistory: 5 unique values
# Purpose: 10 unique values
# CreditAmount: 921 unique values
# Savings: 5 unique values
# EmploymentDuration: 5 unique values
# InstallmentRate: 4 unique values
# PersonalStatusSex: 4 unique values
# OtherDebtors: 3 unique values
# ResidenceDuration: 4 unique values
# Property: 4 unique values
# Age: 53 unique values
# OtherInstallmentPlans: 3 unique values
# Housing: 3 unique values
# ExistingCredits: 4 unique values
# Job: 4 unique values
# PeopleLiable: 2 unique values
# Telephone: 2 unique values
# ForeignWorker: 2 unique values
# Target: 2 unique values

# %% [markdown]
# 4. Fix Target Variable

# %%
df['Target'] = df['Target'].map({1: 0, 2: 1})

print(df['Target'].value_counts())
# Out:
# Target
# 0    700
# 1    300
# Name: count, dtype: int64

# %% [markdown]
# 5. Handle Missing Values

# %%
print('=== Missing Values ===')
print(df.isnull().sum())
# Out:
# === Missing Values ===
# Status                   0
# Duration                 0
# CreditHistory            0
# Purpose                  0
# CreditAmount             0
# Savings                  0
# EmploymentDuration       0
# InstallmentRate          0
# PersonalStatusSex        0
# OtherDebtors             0
# ResidenceDuration        0
# Property                 0
# Age                      0
# OtherInstallmentPlans    0
# Housing                  0
# ExistingCredits          0
# Job                      0
# PeopleLiable             0
# Telephone                0
# ForeignWorker            0
# Target                   0
# dtype: int64

# %% [markdown]
# 6. Explore Target

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Target', data=df)
plt.title('Credit Risk Distribution')
plt.show()

# %% [markdown]
# 7. Encode Categorical Variables

# %%
cat_cols = df.select_dtypes(include='object').columns
print(cat_cols)
# Out:
# Index(['Status', 'CreditHistory', 'Purpose', 'Savings', 'EmploymentDuration',
#        'PersonalStatusSex', 'OtherDebtors', 'Property',
#        'OtherInstallmentPlans', 'Housing', 'Job', 'Telephone',
#        'ForeignWorker'],
#       dtype='object')

# %% [markdown]
# Label Encoding

# %%
le = LabelEncoder()

for col in cat_cols:
    df[col] = le.fit_transform(df[col])

print('✅ Encoding done')
# Out:
# ✅ Encoding done

# %% [markdown]
# 8. Scale Features

# %%
X = df.drop('Target', axis=1)
y = df['Target']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print('✅ Scaling done')
# Out:
# ✅ Scaling done

# %% [markdown]
# 9. Train / Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

print(f'Train: {X_train.shape}')
print(f'Test: {X_test.shape}')
# Out:
# Train: (800, 20)
# Test: (200, 20)

# %% [markdown]
# ⚖️ 10. Handle Imbalance (SMOTE)

# %%
smote = SMOTE(random_state=42)
X_train_bal, y_train_bal = smote.fit_resample(X_train, y_train)

print('✅ SMOTE applied')
print(pd.Series(y_train_bal).value_counts())
# Out:
# ✅ SMOTE applied
# Target
# 1    560
# 0    560
# Name: count, dtype: int64

# %% [markdown]
# 💾 11. Save Cleaned Data

# %%
pd.DataFrame(X_train_bal).to_csv('X_train.csv', index=False)
pd.DataFrame(X_test).to_csv('X_test.csv', index=False)
pd.Series(y_train_bal).to_csv('y_train.csv', index=False)
pd.Series(y_test).to_csv('y_test.csv', index=False)

df.to_csv('german_credit_cleaned.csv', index=False)

print('✅ All files saved successfully!')
# Out:
# ✅ All files saved successfully!

# %% [markdown]
# 🧠 ÉTAPE 1 — Entraîner plusieurs modèles

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "SVM": SVC(probability=True),
    "KNN": KNeighborsClassifier()
}

results = {}

for name, model in models.items():
    model.fit(X_train_bal, y_train_bal)
    acc = model.score(X_test, y_test)
    results[name] = acc
    print(f"{name}: {acc:.4f}")
# Out:
# Logistic Regression: 0.7150
# Random Forest: 0.7600
# SVM: 0.7600
# KNN: 0.6800

# %% [markdown]
# 📊 ÉTAPE 2 — Comparaison des modèles

# %%
import matplotlib.pyplot as plt

plt.bar(results.keys(), results.values())
plt.title("Model Comparison")
plt.ylabel("Accuracy")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# 🎯 ÉTAPE 3 — Matrice de confusion

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

model = RandomForestClassifier()
model.fit(X_train_bal, y_train_bal)

y_pred = model.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %% [markdown]
# 📈 ÉTAPE 4 — ROC Curve

# %%
from sklearn.metrics import roc_curve, auc

y_proba = model.predict_proba(X_test)[:,1]

fpr, tpr, _ = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
plt.plot([0,1],[0,1],'--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %% [markdown]
# ⚙️ ÉTAPE 5 — Hyperparameter Tuning (IMPORTANT 🔥)

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'n_estimators': [50, 100],
    'max_depth': [5, 10]
}

grid = GridSearchCV(RandomForestClassifier(), params, cv=5)
grid.fit(X_train_bal, y_train_bal)

print("Best params:", grid.best_params_)
# Out:
# Best params: {'max_depth': 10, 'n_estimators': 100}

# %% [markdown]
# 💾 ÉTAPE 6 — Sauvegarder le modèle

# %%
import joblib

joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']

# %% [markdown]
# ÉTAPE 7 — (Option avancée MLOps 🔥)

# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (3.10.1)
# Requirement already satisfied: mlflow-skinny==3.10.1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (3.10.1)
# Requirement already satisfied: mlflow-tracing==3.10.1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (3.10.1)
# Requirement already satisfied: Flask-CORS<7 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (6.0.2)
# Requirement already satisfied: Flask<4 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (3.1.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (1.18.4)
# Requirement already satisfied: cryptography<47,>=43.0.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (46.0.5)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: huey<3,>=2.5.4 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (2.6.0)
# Requirement already satisfied: matplotlib<4 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (3.10.8)
# Requirement already satisfied: numpy<3 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<24,>=4.0.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (23.0.1)
# Requirement already satisfied: scikit-learn<2 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (1.7.2)
# Requirement already satisfied: scipy<2 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (1.15.3)
# Requirement already satisfied: skops<1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (0.13.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (2.0.48)
# Requirement already satisfied: waitress<4 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<8,>=5.0.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (7.0.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (0.96.0)
# Requirement already satisfied: fastapi<1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (0.135.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (3.1.46)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (1.40.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (1.40.0)
# Requirement already satisfied: packaging<27 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (6.33.5)
# Requirement already satisfied: pydantic<3,>=2.0.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (1.2.2)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from mlflow-skinny==3.10.1->mlflow) (0.41.0)
# Requirement already satisfied: Mako in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: tomli in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (2.4.0)
# Requirement already satisfied: colorama in c:\users\21695.desktop-e7edrig\appdata\roaming\python\python310\site-packages (from click<9,>=7.0->mlflow-skinny==3.10.1->mlflow) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.1->mlflow) (2.48.0)
# Requirement already satisfied: pywin32>=304 in c:\users\21695.desktop-e7edrig\appdata\roaming\python\python310\site-packages (from docker<8,>=4.0.0->mlflow) (310)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.6.3)
# Requirement already satisfied: starlette>=0.46.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from fastapi<1->mlflow-skinny==3.10.1->mlflow) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from fastapi<1->mlflow-skinny==3.10.1->mlflow) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from fastapi<1->mlflow-skinny==3.10.1->mlflow) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.10.1->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.10.1->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.1->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.1->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from graphene<4->mlflow) (3.2.8)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.10.1->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from matplotlib<4->mlflow) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from matplotlib<4->mlflow) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from matplotlib<4->mlflow) (3.3.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.10.1->mlflow) (0.61b0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from pandas<3->mlflow) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from pandas<3->mlflow) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.10.1->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.10.1->mlflow) (2.41.5)
# Requirement already satisfied: six>=1.5 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.10.1->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.10.1->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.10.1->mlflow) (2026.2.25)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.1->mlflow) (0.6.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from scikit-learn<2->mlflow) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: prettytable>=3.9 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from skops<1->mlflow) (3.17.0)
# Requirement already satisfied: greenlet>=1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.3.2)
# Requirement already satisfied: h11>=0.8 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from uvicorn<1->mlflow-skinny==3.10.1->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (3.0)
# Requirement already satisfied: wcwidth in c:\users\21695.desktop-e7edrig\appdata\roaming\python\python310\site-packages (from prettytable>=3.9->skops<1->mlflow) (0.2.13)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from starlette>=0.46.0->fastapi<1->mlflow-skinny==3.10.1->mlflow) (4.12.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi<1->mlflow-skinny==3.10.1->mlflow) (1.3.1)

# %%
import mlflow
print("MLflow installé ✅")
# Out:
# MLflow installé ✅

# %%
import mlflow

mlflow.start_run()

mlflow.log_param("model", "RandomForest")
mlflow.log_metric("accuracy", model.score(X_test, y_test))

mlflow.end_run()

# %% [markdown]
# Étape 1 — Installer FastAPI et Uvicorn

# %%
# !pip install fastapi uvicorn joblib pandas scikit-learn
# Out:
# Requirement already satisfied: fastapi in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (0.135.1)
# Requirement already satisfied: uvicorn in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (0.41.0)
# Requirement already satisfied: joblib in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (1.5.3)
# Requirement already satisfied: pandas in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (1.7.2)
# Requirement already satisfied: starlette>=0.46.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from fastapi) (0.52.1)
# Requirement already satisfied: pydantic>=2.7.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from fastapi) (2.12.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from fastapi) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: click>=7.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: h11>=0.8 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: colorama in c:\users\21695.desktop-e7edrig\appdata\roaming\python\python310\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from pydantic>=2.7.0->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from pydantic>=2.7.0->fastapi) (2.41.5)
# Requirement already satisfied: six>=1.5 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from starlette>=0.46.0->fastapi) (4.12.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\21695.desktop-e7edrig\anaconda3\envs\mlops\lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi) (3.11)

# %% [markdown]
# Étape 2 — Créer un fichier backend main.py

# %%
# %%writefile main.py

from fastapi import FastAPI
from pydantic import BaseModel
import pandas as pd
import joblib

app = FastAPI(title="German Credit Risk API")

@app.get("/")
def root():
    return {"message": "German Credit Risk API is running ✅"}
# Out:
# Overwriting main.py

# %% [markdown]
# Étape 3 — Définir le schéma des données d’entrée

# %%
from pydantic import BaseModel
class CreditData(BaseModel):
    Status: int
    Duration: float
    CreditHistory: int
    Purpose: int
    CreditAmount: float
    Savings: int
    EmploymentDuration: int
    InstallmentRate: float
    PersonalStatusSex: int
    OtherDebtors: int
    ResidenceDuration: int
    Property: int
    Age: float
    OtherInstallmentPlans: int
    Housing: int
    ExistingCredits: int
    Job: int
    PeopleLiable: int
    Telephone: int
    ForeignWorker: int

# %% [markdown]
# Étape 4 — Endpoint de prédiction

# %%
from fastapi import FastAPI
from pydantic import BaseModel
import pandas as pd

app = FastAPI()
@app.post("/predict")
def predict(data: CreditData):
    # Transformer en DataFrame
    input_df = pd.DataFrame([data.dict()])

    # Appliquer scaling si nécessaire
    input_scaled = scaler.transform(input_df)  # si tu as StandardScaler

    # Prédire
    prediction = model.predict(input_scaled)
    proba = model.predict_proba(input_scaled)[:,1][0]  # probabilité du risque

    return {
        "prediction": int(prediction[0]),
        "risk_probability": float(proba)
    }

# %% [markdown]
# 🧱 Étape 5 — Endpoint test / ping

# %%
@app.get("/")
def root():
    return {"message": "German Credit Risk API is running ✅"}

# %% [markdown]
# 🧱 Étape 6 — Lancer le serveur

# %%
# !pip install nest_asyncio uvicorn --quiet

# %% [markdown]
# 🧱 Étape 8 — Exporter scaler & colonnes (optionnel mais recommandé)

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
# Shape du dataset
print(f"Nombre de lignes    : {df.shape[0]}")
print(f"Nombre de colonnes  : {df.shape[1]}")
print(f"Shape complet       : {df.shape}")
# Out:
# Nombre de lignes    : 1000
# Nombre de colonnes  : 21
# Shape complet       : (1000, 21)

# %%
# Aperçu complet
print(f"Shape : {df.shape}")
print(f"Colonnes : {list(df.columns)}")
df.info()
# Out:
# Shape : (1000, 21)
# Colonnes : ['Status', 'Duration', 'CreditHistory', 'Purpose', 'CreditAmount', 'Savings', 'EmploymentDuration', 'InstallmentRate', 'PersonalStatusSex', 'OtherDebtors', 'ResidenceDuration', 'Property', 'Age', 'OtherInstallmentPlans', 'Housing', 'ExistingCredits', 'Job', 'PeopleLiable', 'Telephone', 'ForeignWorker', 'Target']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Status                 1000 non-null   int32
#  1   Duration               1000 non-null   int64
#  2   CreditHistory          1000 non-null   int32
#  3   Purpose                1000 non-null   int32
#  4   CreditAmount           1000 non-null   int64
#  5   Savings                1000 non-null   int32
#  6   EmploymentDuration     1000 non-null   int32
#  7   InstallmentRate        1000 non-null   int64
#  8   PersonalStatusSex      1000 non-null   int32
#  9   OtherDebtors           1000 non-null   int32
#  10  ResidenceDuration      1000 non-null   int64
#  11  Property               1000 non-null   int32
#  12  Age                    1000 non-null   int64
#  13  OtherInstallmentPlans  1000 non-null   int32
#  14  Housing                1000 non-null   int32
#  15  ExistingCredits        1000 non-null   int64
#  16  Job                    1000 non-null   int32
#  17  PeopleLiable           1000 non-null   int64
#  18  Telephone              1000 non-null   int32
#  19  ForeignWorker          1000 non-null   int32
#  20  Target                 1000 non-null   int64
# dtypes: int32(13), int64(8)
# memory usage: 113.4 KB
